# %% [markdown]
# <a href="https://colab.research.google.com/github/rashisimpi/AIML-Cohort-8-Poaching-Threat-Detection/blob/model-development/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#7. KNN MODEL DEVELOPMENT
knn = KNeighborsClassifier(
n_neighbors=5,
n_jobs=-1
knn.fit(X_train_scaled, y_train)
y_pred_knn = knn.predict(X_test_scaled)
y_prob_knn = knn.predict_proba(X_test_scaled) [:,1]
